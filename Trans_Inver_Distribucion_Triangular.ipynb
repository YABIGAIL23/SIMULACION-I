# %% [markdown]
# <a href="https://colab.research.google.com/github/YABIGAIL23/SIMULACION-I/blob/main/Trans_Inver_Distribucion_Triangular.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###MÉTODO DE TRANSFORMADA INVERSA
# Es un método que permite generar números aleatorios que siguen una distribución específica (como la triangular), partiendo de una variable uniforme
# 𝑈∼u(0,1)

# %% [markdown]
# ###Distribución Triángular
# ![image.png](data:image/png;base64,...)

# %%
#Librerías
import numpy as np
import matplotlib.pyplot as plt
from random import random

# %% [markdown]
# $ x = \begin{cases}
# a + \sqrt{R \cdot (b - a)(c - a)} & \text{si } R < \frac{b-a}{c-a} \\
# c - \sqrt{(1 - R) \cdot (c - b)(c - a)} & \text{si } R \geq \frac{b-a}{c-a}
# \end{cases} $

# %%
#Función de la transformada inversa para la distribucion triangular
def triangular(n):
  a,b,c=1,3,5 #Parametros
  x = [] #Lista vacia
  for i in range(n):
    R = random() #Numeros Aleatorios
    if R<(b-a)/(c-a):
      x.append(a + np.sqrt(R * (b - a) * (c - a)))
    elif R>=(b-a)/(c-a):
      x.append(c - np.sqrt((1 - R) * (c - b) * (c - a)))
  return x

# %%
#Muestras
A = triangular(10000)

# %%
#Histograma
plt.hist(A, bins=100, density=True)
plt.title("Distribución Triangular")
# Out:
# Text(0.5, 1.0, 'Distribución Triangular')

# %%
#Media y varianza
print("Media:", np.mean(A))
print("Varianza:", np.var(A))
# Out:
# Media: 2.996104383019661
# Varianza: 0.664189297126099
